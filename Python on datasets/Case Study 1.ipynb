# %%
#Q1
import pandas as pd
data = pd.read_csv("most_runs_in_cricket.csv", index_col=0)
df = pd.DataFrame(data)
df
# Out:
#                          Player       Span  Mat  Inns  NO   Runs   HS    Ave  \
# 0          SR Tendulkar (INDIA)  1989-2013  664   782  74  34357  248  48.52
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  594   666  67  28016  319  46.77
# 2          RT Ponting (AUS/ICC)  1995-2012  560   668  70  27483  257  45.95
# 3    DPMD Jayawardene (Asia/SL)  1997-2015  652   725  62  25957  374  39.15
# 4        JH Kallis (Afr/ICC/SA)  1995-2014  519   617  97  25534  224  49.10
# ..                          ...        ...  ...   ...  ..    ...  ...    ...
# 83        DB Vengsarkar (INDIA)  1976-1992  245   305  41  10376  166  39.30
# 84         ME Trescothick (ENG)  2000-2006  202   268  16  10326  219  40.97
# 85            G Gambhir (INDIA)  2003-2016  242   283  18  10324  206  38.95
# 86                MD Crowe (NZ)  1982-1995  220   271  29  10148  299  41.93
# 87              GW Flower (ZIM)  1992-2010  288   337  24  10028  201  32.03
#
#         BF     SR  100   50   0    4s   6s
# ...

# %%
df.shape
# Out:
# (88, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88 entries, 0 to 87
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  88 non-null     object
#  1   Span    88 non-null     object
#  2   Mat     88 non-null     int64
#  3   Inns    88 non-null     int64
#  4   NO      88 non-null     int64
#  5   Runs    88 non-null     int64
#  6   HS      88 non-null     int64
#  7   Ave     88 non-null     float64
#  8   BF      88 non-null     object
#  9   SR      88 non-null     float64
#  10  100     88 non-null     int64
#  11  50      88 non-null     int64
#  12  0       88 non-null     int64
#  13  4s      88 non-null     int64
#  14  6s      88 non-null     int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 11.0+ KB

# %%
df.describe()
# Out:
#               Mat        Inns          NO          Runs          HS  \
# count   88.000000   88.000000   88.000000     88.000000   88.000000
# mean   365.431818  421.329545   46.943182  15301.284091  241.784091
# std    104.135830  107.002495   24.002566   4665.091415   57.521100
# min    202.000000  252.000000   12.000000  10028.000000  135.000000
# 25%    285.750000  337.000000   30.750000  11728.500000  199.750000
# 50%    360.500000  410.000000   41.000000  13986.000000  232.500000
# 75%    425.250000  467.250000   62.250000  17274.500000  278.500000
# max    664.000000  782.000000  142.000000  34357.000000  400.000000
#
#              Ave          SR         100          50          0           4s  \
# count  88.000000   88.000000   88.000000   88.000000  88.000000    88.000000
# mean   40.816364   66.841818   31.034091   83.579545  25.284091  1593.363636
# std     5.230841   12.652238   15.438010   24.978944   8.992908   547.409263
# ...

# %%
#Q2
print(len(df))
# Out:
# 88

# %%
df.head(10)
# Out:
#                         Player       Span  Mat  Inns  NO   Runs   HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2013  664   782  74  34357  248  48.52
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  594   666  67  28016  319  46.77
# 2         RT Ponting (AUS/ICC)  1995-2012  560   668  70  27483  257  45.95
# 3   DPMD Jayawardene (Asia/SL)  1997-2015  652   725  62  25957  374  39.15
# 4       JH Kallis (Afr/ICC/SA)  1995-2014  519   617  97  25534  224  49.10
# 5    R Dravid (Asia/ICC/INDIA)  1996-2012  509   605  72  24208  270  45.41
# 6              V Kohli (INDIA)  2008-2022  473   527  77  24130  254  53.62
# 7             BC Lara (ICC/WI)  1990-2007  430   521  38  22358  400  46.28
# 8      ST Jayasuriya (Asia/SL)  1989-2011  586   651  35  21032  340  34.14
# 9           S Chanderpaul (WI)  1994-2015  454   553  94  20988  203  45.72
#
#        BF     SR  100   50   0    4s   6s
# 0  50817+  67.58  100  164  34  4076  264
# 1   42086  66.56   63  153  28  3015  159
# ...

# %%
df.tail()
# Out:
#                    Player       Span  Mat  Inns  NO   Runs   HS    Ave  \
# 83  DB Vengsarkar (INDIA)  1976-1992  245   305  41  10376  166  39.30
# 84   ME Trescothick (ENG)  2000-2006  202   268  16  10326  219  40.97
# 85      G Gambhir (INDIA)  2003-2016  242   283  18  10324  206  38.95
# 86          MD Crowe (NZ)  1982-1995  220   271  29  10148  299  41.93
# 87        GW Flower (ZIM)  1992-2010  288   337  24  10028  201  32.03
#
#         BF     SR  100  50   0    4s  6s
# 83  15989+  50.04   18  58  22   737  41
# 84   15903  64.93   26  52  25  1382  84
# 85   14994  68.85   20  63  20  1188  37
# 86   18666  54.36   21  52  12  1037  56
# 87   19736  50.81   12  55  34   906  53

# %%
#Q3
df.iloc[df.Mat.argmax(), 0:3]
# Out:
# Player    SR Tendulkar (INDIA)
# Span                 1989-2013
# Mat                        664
# Name: 0, dtype: object

# %%
df.iloc[df.Inns.argmax(), 0:4]
# Out:
# Player    SR Tendulkar (INDIA)
# Span                 1989-2013
# Mat                        664
# Inns                       782
# Name: 0, dtype: object

# %%
df.iloc[df.Runs.argmax(), 0:6]
# Out:
# Player    SR Tendulkar (INDIA)
# Span                 1989-2013
# Mat                        664
# Inns                       782
# NO                          74
# Runs                     34357
# Name: 0, dtype: object

# %%
#Q4
df.iloc[df.Mat.argmin(), 0:3]
# Out:
# Player    ME Trescothick (ENG)
# Span                 2000-2006
# Mat                        202
# Name: 84, dtype: object

# %%
df.iloc[df.Inns.argmin(), 0:4]
# Out:
# Player    Babar Azam (PAK)
# Span             2015-2022
# Mat                    226
# Inns                   252
# Name: 77, dtype: object

# %%
df.iloc[df.Runs.argmin(), 0:6]
# Out:
# Player    GW Flower (ZIM)
# Span            1992-2010
# Mat                   288
# Inns                  337
# NO                     24
# Runs                10028
# Name: 87, dtype: object

# %%
#Q5
df['Player'].count()
# Out:
# 88

# %%
df[['Player', 'Ave']]
# Out:
#                          Player    Ave
# 0          SR Tendulkar (INDIA)  48.52
# 1   KC Sangakkara (Asia/ICC/SL)  46.77
# 2          RT Ponting (AUS/ICC)  45.95
# 3    DPMD Jayawardene (Asia/SL)  39.15
# 4        JH Kallis (Afr/ICC/SA)  49.10
# ..                          ...    ...
# 83        DB Vengsarkar (INDIA)  39.30
# 84         ME Trescothick (ENG)  40.97
# 85            G Gambhir (INDIA)  38.95
# 86                MD Crowe (NZ)  41.93
# 87              GW Flower (ZIM)  32.03
#
# [88 rows x 2 columns]

# %%
import re
Names =[]
Country=[]
for x in df['Player']:
    a=  re.split("[()\xa0]", x)
    Names.append(a[0])
    b = re.split("/",a[1])
    for y in b:
        if(y!='Asia' and y!='ICC' and y!='Afr' and y!='IRE'):
            Country.append(y)

Names = pd.Series(Names, name='Player Name')
Country = pd.Series(Country, name='Country Name')
df['Player Name']= Names
df['Country']=Country

print(Names)
print(Country)
# Out:
# 0         SR Tendulkar
# 1        KC Sangakkara
# 2           RT Ponting
# 3     DPMD Jayawardene
# 4            JH Kallis
#             ...
# 83       DB Vengsarkar
# 84      ME Trescothick
# 85           G Gambhir
# 86            MD Crowe
# 87           GW Flower
# Name: Player Name, Length: 88, dtype: object
# 0     INDIA
# 1        SL
# 2       AUS
# 3        SL
# 4        SA
#       ...
# 86    INDIA
# 87      ENG
# 88    INDIA
# 89       NZ
# 90      ZIM
# Name: Country Name, Length: 91, dtype: object

# %%
df.groupby(['Country','Player Name'])[['Ave']].min()
# Out:
#                          Ave
# Country Player Name
# AUS     DA Warner      43.10
#         EJG Morgan     35.60
#         LRPL Taylor    42.72
#         ME Waugh       40.51
#         MV Boucher     29.00
# ...                      ...
# WI      Shoaib Malik   33.90
# World   HH Gibbs       37.30
#         MN Samuels     32.27
#         SC Ganguly     41.46
# ZIM     DI Gower       39.44
#
# [88 rows x 1 columns]

# %%
#Q6
b = 0
a = 0
for index in df.index:
    # converting BF to int and removing '+'
    df['BF'][index] = int(df['BF'][index].replace('+', ''))
    if (df['Runs'][index] / df['BF'][index]) > b:
        b = (df['Runs'][index] / df['BF'][index])
        a = index
print(df.iloc[a])
# Out:
# Player         Shahid Afridi (Asia/ICC/PAK)
# Span                              1996-2018
# Mat                                     524
# Inns                                    508
# NO                                       40
# Runs                                  11196
# HS                                      156
# Ave                                   23.92
# BF                                     9809
# SR                                   114.14
# 100                                      11
# 50                                       51
# 0                                        44
# 4s                                     1053
# 6s                                      476
# Player Name                  Shahid Afridi
# Country                                 ENG
# Name: 71, dtype: object
# C:\Users\Jay\AppData\Local\Temp/ipykernel_4744/4148238973.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#Q7
import re
Start_Y =[]
End_Y=[]
for x in df['Span']:
    a=  re.split("-", x)
    Start_Y.append(int(a[0]))
    End_Y.append(int(a[1]))

Start_Y = pd.Series(Start_Y, name='Beginning Year')
End_Y = pd.Series(End_Y, name='Retire Year')

df['Career_Span'] = End_Y - Start_Y

x = df[df.Career_Span == df.Career_Span.max()]
x
# Out:
#                  Player       Span  Mat  Inns  NO   Runs   HS    Ave      BF  \
# 0  SR Tendulkar (INDIA)  1989-2013  664   782  74  34357  248  48.52  50817+
#
#       SR  100   50   0    4s   6s    Player Name Country  Career Span  \
# 0  67.58  100  164  34  4076  264  SR Tendulkar    INDIA           24
#
#    Career_Span
# 0           24

# %%
x = df['Country'].value_counts()
x.head(1)
# Out:
# INDIA    13
# Name: Country, dtype: int64

# %%
#Q8
import re
Start_Y =[]
End_Y=[]
for x in df['Span']:
    a=  re.split("-", x)
    Start_Y.append(int(a[0]))
    End_Y.append(int(a[1]))

Start_Y = pd.Series(Start_Y, name='Beginning Year')
End_Y = pd.Series(End_Y, name='Retire Year')

df['Last Playing Year'] = End_Y
df[df['Last Playing Year'] == 2022]
# Out:
#                          Player       Span  Mat  Inns  NO   Runs   HS    Ave  \
# 6               V Kohli (INDIA)  2008-2022  473   527  77  24130  254  53.62
# 16             LRPL Taylor (NZ)  2006-2022  450   510  84  18199  290  42.72
# 20                JE Root (ENG)  2012-2022  314   405  46  17604  254  49.03
# 27              DA Warner (AUS)  2009-2022  329   407  25  16466  335  43.10
# 28            RG Sharma (INDIA)  2007-2022  420   437  59  16250  264  42.98
# 31           KS Williamson (NZ)  2010-2022  324   381  39  15889  251  46.45
# 39  Tamim Iqbal (BAN/ICC/World)  2007-2022  378   439  18  14914  206  35.42
# 44              AD Mathews (SL)  2008-2022  396   429  90  13936  200  41.10
# 45              SPD Smith (AUS)  2010-2022  285   325  43  13887  239  49.24
# 47        Mushfiqur Rahim (BAN)  2005-2022  420   465  66  13509  219  33.85
# 48              MJ Guptill (NZ)  2009-2022  367   402  27  13463  237  35.90
# ...

# %%
#Q9
contain_M = df[df['Player'].str.contains('M|m')]
contain_M
# Out:
#                            Player       Span  Mat  Inns   NO   Runs   HS  \
# 3      DPMD Jayawardene (Asia/SL)  1997-2015  652   725   62  25957  374
# 10  Inzamam-ul-Haq (Asia/ICC/PAK)  1991-2007  499   551   76  20580  329
# 13             HM Amla (SA/World)  2004-2019  349   437   36  18672  311
# 19                TM Dilshan (SL)  1999-2016  497   527   64  17671  193
# 21     Mohammad Yousuf (Asia/PAK)  1998-2010  381   432   52  17300  223
# 22          MS Dhoni (Asia/INDIA)  2004-2019  538   526  142  17266  224
# 24          GC Smith (Afr/ICC/SA)  2002-2014  347   432   25  17236  277
# 25                MJ Clarke (AUS)  2003-2015  394   449   71  17112  329
# 26                 ME Waugh (AUS)  1988-2002  372   445   37  16529  173
# 28              RG Sharma (INDIA)  2007-2022  420   437   59  16250  264
# 29            Javed Miandad (PAK)  1975-1996  357   407   62  16213  280
# 31             KS Williamson (NZ)  2010-2022  324   381   39  15889  251
# ...

# %%
#Q10
df[df['100']==df['100'].max()]
# Out:
#                  Player       Span  Mat  Inns  NO   Runs   HS    Ave      BF  \
# 0  SR Tendulkar (INDIA)  1989-2013  664   782  74  34357  248  48.52  50817+
#
#       SR  100   50   0    4s   6s  Last Playing Year
# 0  67.58  100  164  34  4076  264               2013

# %%
df[df['4s']==df['4s'].max()]
# Out:
#                  Player       Span  Mat  Inns  NO   Runs   HS    Ave      BF  \
# 0  SR Tendulkar (INDIA)  1989-2013  664   782  74  34357  248  48.52  50817+
#
#       SR  100   50   0    4s   6s  Last Playing Year
# 0  67.58  100  164  34  4076  264               2013

# %%
df[df['6s']==df['6s'].max()]
# Out:
#                Player       Span  Mat  Inns  NO   Runs   HS    Ave     BF  \
# 12  CH Gayle (ICC/WI)  1999-2021  483   551  35  19593  333  37.97  25370
#
#        SR  100   50   0    4s   6s  Last Playing Year
# 12  77.22   42  105  44  2332  553               2021

# %%
df[df['100']==df['100'].min()]
# Out:
#                      Player       Span  Mat  Inns  NO   Runs   HS   Ave  \
# 81  MV Boucher (Afr/ICC/SA)  1997-2012  467   448  87  10469  147  29.0
#
#        BF     SR  100  50   0    4s   6s  Last Playing Year
# 81  16808  62.28    6  61  33  1034  105               2012

# %%
df[df['4s']==df['4s'].min()]
# Out:
#                    Player       Span  Mat  Inns  NO   Runs   HS   Ave      BF  \
# 83  DB Vengsarkar (INDIA)  1976-1992  245   305  41  10376  166  39.3  15989+
#
#        SR  100  50   0   4s  6s  Last Playing Year
# 83  50.04   18  58  22  737  41               1992

# %%
df[df['6s']==df['6s'].min()]
# Out:
#                 Player       Span  Mat  Inns  NO   Runs   HS    Ave     BF  \
# 75  VVS Laxman (INDIA)  1996-2012  220   308  41  11119  281  41.64  21067
#
#        SR  100  50   0    4s  6s  Last Playing Year
# 75  52.77   23  66  17  1357   9               2012
